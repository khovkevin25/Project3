# %%
import pandas as pd

# %%
df = pd.read_csv("Philadelphia_Food_Access.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 19 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Census Tract                                          381 non-null    int64
#  1   Population                                            381 non-null    int64
#  2   Housing Units in Tract                                381 non-null    int64
#  3   LI, LA - 1 mile radius                                381 non-null    int64
#  4   LI, LA - 0.5 mile radius                              381 non-null    int64
#  5   Low Income Tracts                                     381 non-null    int64
#  6   Poverty Rate (%)                                      381 non-null    float64
#  7   Median Family Income                                  369 non-null    float64
# ...

# %%
df['Snap Percentage'] = df['Snap Percentage'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 19 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Census Tract                                          381 non-null    int64
#  1   Population                                            381 non-null    int64
#  2   Housing Units in Tract                                381 non-null    int64
#  3   LI, LA - 1 mile radius                                381 non-null    int64
#  4   LI, LA - 0.5 mile radius                              381 non-null    int64
#  5   Low Income Tracts                                     381 non-null    int64
#  6   Poverty Rate (%)                                      381 non-null    float64
#  7   Median Family Income                                  369 non-null    float64
# ...

# %%
df.to_csv("Philadelphia_Food_Access2.csv", index = False)

# %%
SuperCleaned.head()
# Out:
#    Census Tract  Population  Housing Units in Tract  LI, LA - 1 mile radius  \
# 0   42101000100        3478                    2301                       0
# 1   42101000200        2937                    1145                       0
# 2   42101000300        3169                    1855                       0
# 3   42101000401        2125                    1584                       0
# 4   42101000402        3142                    2273                       0
#
#    LI, LA - 0.5 mile radius  Low Income Tracts  Poverty Rate (%)  \
# 0                         0                  0          6.937110
# 1                         0                  1         29.253366
# 2                         0                  0          9.255220
# 3                         0                  0         17.697394
# 4                         0                  0          4.690722
#
#    Median Family Income  LA - 1 mile radius  LA - 0.5 mile radius  \
# ...

# %%
SuperCleaned['Poverty Rate (%)'] = SuperCleaned['Poverty Rate (%)'].astype(float)

# %%
SuperCleaned.style.format({'Poverty Rate (%)': '{:,.2f}'.format, 'Median Family Income': '{:,.2f}'.format, 'LA,LI - 0.5 mile radius': '{:,.2f}'.format, 'LA - Kids population, 0.5 mile radius': '{:,.2f}'.format, 'LA - Senior population, 0.5 mile radius': '{:,.2f}'.format, 'LA - Kids population, 1 mile radius': '{:,.2f}'.format, 'LA - Senior population, 1 mile radius': '{:,.2f}'.format,'LA - Housing Units w/ Snap Benefits, 0.5 mile radius': '{:,.2f}'.format, 'LA - Housing Units w/ Snap Benefits, 1 mile radius': '{:,.2f}'.format})
# Out:
# <style type="text/css">
# </style>
# <table id="T_247f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_247f1_level0_col0" class="col_heading level0 col0" >Census Tract</th>
#       <th id="T_247f1_level0_col1" class="col_heading level0 col1" >Population</th>
#       <th id="T_247f1_level0_col2" class="col_heading level0 col2" >Housing Units in Tract</th>
#       <th id="T_247f1_level0_col3" class="col_heading level0 col3" >LI, LA - 1 mile radius</th>
#       <th id="T_247f1_level0_col4" class="col_heading level0 col4" >LI, LA - 0.5 mile radius</th>
#       <th id="T_247f1_level0_col5" class="col_heading level0 col5" >Low Income Tracts</th>
#       <th id="T_247f1_level0_col6" class="col_heading level0 col6" >Poverty Rate (%)</th>
#       <th id="T_247f1_level0_col7" class="col_heading level0 col7" >Median Family Income</th>
#       <th id="T_247f1_level0_col8" class="col_heading level0 col8" >LA - 1 mile radius</th>
# ...

# %%
SuperCleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 18 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Census Tract                                          381 non-null    int64
#  1   Population                                            381 non-null    int64
#  2   Housing Units in Tract                                381 non-null    int64
#  3   LI, LA - 1 mile radius                                381 non-null    int64
#  4   LI, LA - 0.5 mile radius                              381 non-null    int64
#  5   Low Income Tracts                                     381 non-null    int64
#  6   Poverty Rate (%)                                      381 non-null    float64
#  7   Median Family Income                                  369 non-null    float64
# ...

# %%
SuperCleaned.to_csv("Philadelphia Food Access.csv", index = False)
