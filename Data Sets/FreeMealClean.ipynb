# %%
import pandas as pd

# %%
df = pd.read_csv("free_meal_sites_philly.csv")

# %%
df.head()
# Out:
#    objectid                        site_name                      address  \
# 0       104       Nativity Satellite Program             3255 Belgrade St
# 1       118          King Older Adult Center  2100 W. Cecil B. Moore Ave.
# 2       219            Bethel Worship Center          169 W. Wyoming Ave.
# 3       220           Hope Prison Ministries            735 W. Butler St.
# 4       221  Frontline Dads (410 N 34th St.)                410 N 34th St
#
#      phone_number            category  zip_code  temporary_closure  \
# 0    215-423-2772                 PCA   19134.0                NaN
# 1    215-685-2715          PPR_Senior   19121.0                NaN
# 2    267-979-3718  SHARE FOOD PROGRAM   19120.0                NaN
# 3    610-633-1789  SHARE FOOD PROGRAM   19120.0                NaN
# 4  (484) 532-8772  SHARE FOOD PROGRAM   19104.0                NaN
#
#       category_type  site_key              status  ... hours_sat_start2  \
# ...

# %%
Cleaned = df[["site_name","address", "category", "category_type", "status", "x", "y"]]

# %%
Cleaned.head()
# Out:
#                          site_name                      address  \
# 0       Nativity Satellite Program             3255 Belgrade St
# 1          King Older Adult Center  2100 W. Cecil B. Moore Ave.
# 2            Bethel Worship Center          169 W. Wyoming Ave.
# 3           Hope Prison Ministries            735 W. Butler St.
# 4  Frontline Dads (410 N 34th St.)                410 N 34th St
#
#              category     category_type              status          x  \
# 0                 PCA  Senior Meal Site              Active -75.102783
# 1          PPR_Senior  Senior Meal Site              Active -75.169604
# 2  SHARE FOOD PROGRAM         Food Site              Active -75.127020
# 3  SHARE FOOD PROGRAM         Food Site              Active -75.137593
# 4  SHARE FOOD PROGRAM         Food Site  Permanently Closed -75.191289
#
#            y
# 0  39.986910
# 1  39.979985
# 2  40.022040
# 3  40.026497
# 4  39.961708

# %%
SuperCleaned = Cleaned.rename(columns={"site_name":"Site", "address": "Address", "category": "Category", "category_type": "Sub-category", "status": "Status", "x": "Longitude", "y": "Latitude"})

# %%
SuperCleaned.head()
# Out:
#                               Site                      Address  \
# 0       Nativity Satellite Program             3255 Belgrade St
# 1          King Older Adult Center  2100 W. Cecil B. Moore Ave.
# 2            Bethel Worship Center          169 W. Wyoming Ave.
# 3           Hope Prison Ministries            735 W. Butler St.
# 4  Frontline Dads (410 N 34th St.)                410 N 34th St
#
#              Category      Sub-category              Status  Longitude  \
# 0                 PCA  Senior Meal Site              Active -75.102783
# 1          PPR_Senior  Senior Meal Site              Active -75.169604
# 2  SHARE FOOD PROGRAM         Food Site              Active -75.127020
# 3  SHARE FOOD PROGRAM         Food Site              Active -75.137593
# 4  SHARE FOOD PROGRAM         Food Site  Permanently Closed -75.191289
#
#     Latitude
# 0  39.986910
# 1  39.979985
# 2  40.022040
# 3  40.026497
# 4  39.961708

# %%
SuperCleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 283 entries, 0 to 282
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Site          282 non-null    object
#  1   Address       281 non-null    object
#  2   Category      282 non-null    object
#  3   Sub-category  281 non-null    object
#  4   Status        281 non-null    object
#  5   Longitude     175 non-null    float64
#  6   Latitude      175 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 15.6+ KB

# %%
SuperCleaned.to_csv("FreeMealsClean.csv", index = False)
