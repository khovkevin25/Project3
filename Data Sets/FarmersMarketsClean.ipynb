# %%
import pandas as pd

# %%
df = pd.read_csv("Farmers_Markets_Philly.csv")

# %%
df.head()
# Out:
#            X          Y  objectid                              globalid  \
# 0 -75.220694  40.025777         1  02394865-c6e5-48d7-8162-0c7929b21bdf
# 1 -75.171580  39.950286         2  56f87743-3148-4acf-b76f-93737cde82f2
# 2 -75.215926  39.932614         3  715fa94c-8798-4159-8121-f0de852747da
# 3 -75.156717  39.950026         4  2f4f4aff-b33b-43d7-9f9f-0f8c73af04f6
# 4 -75.162307  39.931053         5  f656f958-3eba-4719-a89e-2ddd10cc173b
#
#                  editdate                           name  \
# 0  2025/01/23 05:02:36+00   Pretzel Park Farmers' Market
# 1  2025/01/23 05:02:36+00    Rittenhouse Farmers' Market
# 2  2025/01/23 05:02:36+00              Sankofa Farmstand
# 3  2025/01/23 05:02:36+00      Jefferson Farmers' Market
# 4  2025/01/23 05:02:36+00  East Passyunk Farmers' Market
#
#                          operator                  address    zip  \
# 0         Friends of Pretzel Park   4300 Silverwood Street  19127
# ...

# %%
Cleaned = df[["objectid","name", "address", "zip", "payment_snap", "X", "Y"]]

# %%
Cleaned.head()
# Out:
#    objectid                           name                  address    zip  \
# 0         1   Pretzel Park Farmers' Market   4300 Silverwood Street  19127
# 1         2    Rittenhouse Farmers' Market       1800 Walnut Street  19103
# 2         3              Sankofa Farmstand  54th and Lindbergh Blvd  19144
# 3         4      Jefferson Farmers' Market      925 Chestnut Street  19107
# 4         5  East Passyunk Farmers' Market  1430 E. Passyunk Avenue  19147
#
#   payment_snap          X          Y
# 0           No -75.220694  40.025777
# 1           No -75.171580  39.950286
# 2          Yes -75.215926  39.932614
# 3           No -75.156717  39.950026
# 4           No -75.162307  39.931053

# %%
SuperCleaned = Cleaned.rename(columns={"objectid":"Count", "name": "Name", "address": "Address", "zip": "Zipcode", "payment_snap": "Accepts SNAP", "X": "Longitude", "Y": "Latitude"})

# %%
SuperCleaned.head()
# Out:
#    Count                           Name                  Address  Zipcode  \
# 0      1   Pretzel Park Farmers' Market   4300 Silverwood Street    19127
# 1      2    Rittenhouse Farmers' Market       1800 Walnut Street    19103
# 2      3              Sankofa Farmstand  54th and Lindbergh Blvd    19144
# 3      4      Jefferson Farmers' Market      925 Chestnut Street    19107
# 4      5  East Passyunk Farmers' Market  1430 E. Passyunk Avenue    19147
#
#   Accepts SNAP  Longitude   Latitude
# 0           No -75.220694  40.025777
# 1           No -75.171580  39.950286
# 2          Yes -75.215926  39.932614
# 3           No -75.156717  39.950026
# 4           No -75.162307  39.931053

# %%
SuperCleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Count         22 non-null     int64
#  1   Name          22 non-null     object
#  2   Address       22 non-null     object
#  3   Zipcode       22 non-null     int64
#  4   Accepts SNAP  21 non-null     object
#  5   Longitude     22 non-null     float64
#  6   Latitude      22 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.3+ KB

# %%
SuperCleaned.to_csv("FarmersMarketClean.csv", index = False)
