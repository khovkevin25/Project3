# %%
import pandas as pd

# %%
df = pd.read_excel("FoodAccess.xlsx", sheet_name = 'Food Access Research Atlas')

# %%
df.head()
# Out:
#    CensusTract         State               County  Urban  Pop2010  OHU2010  \
# 0  42101000100  Pennsylvania  Philadelphia County      1     3478     2301
# 1  42101000200  Pennsylvania  Philadelphia County      1     2937     1145
# 2  42101000300  Pennsylvania  Philadelphia County      1     3169     1855
# 3  42101000401  Pennsylvania  Philadelphia County      1     2125     1584
# 4  42101000402  Pennsylvania  Philadelphia County      1     3142     2273
#
#    GroupQuartersFlag  NUMGQTRS   PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0        27   0.776308                  0  ...
# 1                  0       428  14.572693                  0  ...
# 2                  0       202   6.374251                  0  ...
# 3                  0        38   1.788235                  0  ...
# 4                  0        46   1.464036                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# ...

# %%
Cleaned = df[["CensusTract","Pop2010", "OHU2010", "LILATracts_1And10", "LILATracts_halfAnd10", "LowIncomeTracts", "PovertyRate", "MedianFamilyIncome", "LA1and10", "LAhalfand10", "lalowihalf", "lakidshalf", "laseniorshalf", "lakids1", "laseniors1","lasnaphalf","lasnap1", "TractSNAP"]]

# %%
Cleaned.head()
# Out:
#    CensusTract  Pop2010  OHU2010  LILATracts_1And10  LILATracts_halfAnd10  \
# 0  42101000100     3478     2301                  0                     0
# 1  42101000200     2937     1145                  0                     0
# 2  42101000300     3169     1855                  0                     0
# 3  42101000401     2125     1584                  0                     0
# 4  42101000402     3142     2273                  0                     0
#
#    LowIncomeTracts  PovertyRate  MedianFamilyIncome  LA1and10  LAhalfand10  \
# 0                0     6.937110            124729.0         0            0
# 1                1    29.253366             47806.0         0            0
# 2                0     9.255220            143482.0         0            0
# 3                0    17.697394            129531.0         0            0
# 4                0     4.690722            125917.0         0            0
#
# ...

# %%
SuperCleaned = Cleaned.rename(columns={"CensusTract":"Census Tract", "Pop2010": "Population", "OHU2010": "Housing Units in Tract", "LILATracts_1And10": "LI, LA - 1 mile radius", "LILATracts_halfAnd10": "LI, LA - 0.5 mile radius", "LowIncomeTracts": "Low Income Tracts", "PovertyRate": "Poverty Rate (%)", "MedianFamilyIncome": "Median Family Income", "LA1and10": "LA - 1 mile radius", "LAhalfand10": "LA - 0.5 mile radius", "lalowihalf": "LA,LI - 0.5 mile radius", "lakidshalf": "LA - Kids population, 0.5 mile radius", "laseniorshalf": "LA - Senior population, 0.5 mile radius","lakids1": "LA - Kids population, 1 mile radius", "laseniors1": "LA - Senior population, 1 mile radius", "lasnaphalf": "LA - Housing Units w/ Snap Benefits, 0.5 mile radius","lasnap1": "LA - Housing Units w/ Snap Benefits, 1 mile radius", "TractSNAP": "Total Count of Housing w/ Snap Benefits"})

# %%
SuperCleaned.head()
# Out:
#    Census Tract  Population  Housing Units in Tract  LI, LA - 1 mile radius  \
# 0   42101000100        3478                    2301                       0
# 1   42101000200        2937                    1145                       0
# 2   42101000300        3169                    1855                       0
# 3   42101000401        2125                    1584                       0
# 4   42101000402        3142                    2273                       0
#
#    LI, LA - 0.5 mile radius  Low Income Tracts  Poverty Rate (%)  \
# 0                         0                  0          6.937110
# 1                         0                  1         29.253366
# 2                         0                  0          9.255220
# 3                         0                  0         17.697394
# 4                         0                  0          4.690722
#
#    Median Family Income  LA - 1 mile radius  LA - 0.5 mile radius  \
# ...

# %%
SuperCleaned['Poverty Rate (%)'] = SuperCleaned['Poverty Rate (%)'].astype(float)

# %%
SuperCleaned.style.format({'Poverty Rate (%)': '{:,.2f}'.format, 'Median Family Income': '{:,.2f}'.format, 'LA,LI - 0.5 mile radius': '{:,.2f}'.format, 'LA - Kids population, 0.5 mile radius': '{:,.2f}'.format, 'LA - Senior population, 0.5 mile radius': '{:,.2f}'.format, 'LA - Kids population, 1 mile radius': '{:,.2f}'.format, 'LA - Senior population, 1 mile radius': '{:,.2f}'.format,'LA - Housing Units w/ Snap Benefits, 0.5 mile radius': '{:,.2f}'.format, 'LA - Housing Units w/ Snap Benefits, 1 mile radius': '{:,.2f}'.format})

# %%
SuperCleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 18 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Census Tract                                          381 non-null    int64
#  1   Population                                            381 non-null    int64
#  2   Housing Units in Tract                                381 non-null    int64
#  3   LI, LA - 1 mile radius                                381 non-null    int64
#  4   LI, LA - 0.5 mile radius                              381 non-null    int64
#  5   Low Income Tracts                                     381 non-null    int64
#  6   Poverty Rate (%)                                      381 non-null    float64
#  7   Median Family Income                                  369 non-null    float64
# ...

# %%
SuperCleaned.to_excel("Philadelphia Food Access.xlsx", index = False)
